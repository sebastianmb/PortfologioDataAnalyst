# %% [markdown]
# # Stadistic Analisis ZHG U y R

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_R= pd.read_excel(r"D:\IGAC_2024\Procesamiento\Diagnostico_ZH_Vigent\BD\ZHG_Vigentes\MERGE_R_ZHG_Coor.xlsx")

# %%
df_R.head()
# Out:
#    OBJECTID   CODIGO  CODIGO_ZON  VALOR_HECT SUBZONA_FI             VIGENCIA  \
# 0     11248  1383600           1  7000000000             2014-01-01 00:00:00
# 1     11249  1383600           2  5000000000             2014-01-01 00:00:00
# 2     11250  1383600           3  2000000000             2014-01-01 00:00:00
# 3     11251  1383600           4  1200000000             2014-01-01 00:00:00
# 4     11252  1383600           4  1200000000             2014-01-01 00:00:00
#
#    codigo_mun  CODIGO_DEP MpNombre    Depto          ha       Long       Lat
# 0       13836          13  Turbaco  Bolívar  120.518003 -75.379744  10.35295
# 1       13836          13  Turbaco  Bolívar   15.015539 -75.379744  10.35295
# 2       13836          13  Turbaco  Bolívar   81.873921 -75.379744  10.35295
# 3       13836          13  Turbaco  Bolívar    2.897438 -75.379744  10.35295
# 4       13836          13  Turbaco  Bolívar    8.617032 -75.379744  10.35295

# %%
df_R.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30608 entries, 0 to 30607
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OBJECTID    30608 non-null  int64
#  1   CODIGO      30608 non-null  int64
#  2   CODIGO_ZON  30608 non-null  int64
#  3   VALOR_HECT  30608 non-null  int64
#  4   SUBZONA_FI  30608 non-null  object
#  5   VIGENCIA    30608 non-null  object
#  6   codigo_mun  30608 non-null  int64
#  7   CODIGO_DEP  30608 non-null  int64
#  8   MpNombre    30608 non-null  object
#  9   Depto       30608 non-null  object
#  10  ha          30608 non-null  float64
#  11  Long        30608 non-null  float64
#  12  Lat         30608 non-null  float64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 3.0+ MB

# %%
df_R.describe()
# Out:
#            OBJECTID        CODIGO    CODIGO_ZON    VALOR_HECT    codigo_mun  \
# count  30608.000000  3.060800e+04  30608.000000  3.060800e+04  30608.000000
# mean   16917.751438  4.265382e+06      8.984220  3.412069e+06  42653.819034
# std     9382.082466  2.622052e+06      4.322243  5.785968e+07  26220.517368
# min      504.000000  1.306200e+06      1.000000  0.000000e+00  13062.000000
# 25%     8549.750000  1.354900e+06      7.000000  1.000000e+04  13549.000000
# 50%    17064.500000  4.427900e+06      8.000000  3.000000e+05  44279.000000
# 75%    25227.250000  6.867900e+06     12.000000  1.400000e+06  68679.000000
# max    32884.000000  7.082300e+06     31.000000  7.000000e+09  70823.000000
#
#          CODIGO_DEP             ha          Long           Lat
# count  30608.000000   30608.000000  30608.000000  30608.000000
# mean      42.173451     361.478562    -74.270891      8.312826
# std       26.208785    4806.113821      0.894367      1.283551
# ...

# %%
df_R.plot(x='VALOR_HECT', y='ha')
# Out:
# <Axes: xlabel='VALOR_HECT'>
